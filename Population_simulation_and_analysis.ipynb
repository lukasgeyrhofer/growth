# %%
from imp import reload
import numpy as np
import pandas as pd
import sys

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib notebook
matplotlib.rcParams['figure.figsize'] = [8,6]

import stochasticgrowth_eventline as sge
sge = reload(sge)

# %%
p1 = sge.Population(alpha=.1,beta=.6,eigenvalues=[.9,.01],initialpopulationsize = 10)
p1.growth(divisionevents = 5000)

p2 = sge.Population(initialpopulationsize = 10)
p2.growth(divisionevents = 5000)

# %%
data1 = p1.divisiondata
data2 = p2.divisiondata

plt.scatter(data1['times'],data1['divisiontimes'],marker='.',s=5)
plt.scatter(data2['times'],data2['divisiontimes'],marker='.',s=5)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
print(p1.divtimes.mean,p1.divtimes.variance)
print(p2.divtimes.mean,p2.divtimes.variance)
# Out:
# None 0.009999999999999998
# None 0.010000000000000005
